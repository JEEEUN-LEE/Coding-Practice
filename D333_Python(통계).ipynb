# %% [markdown]
# ## 5️⃣ 확률과 확률분포 (Probability & Probability Distribution)
#
# ---
#
# ### 🔹 확률 (Probability)
#
# - 어떤 데이터를 얻을 수 있는 **가능성의 정도**를 **확률(Probability, P)** 로 표기한다.
#   예: 주사위를 던졌을 때 ‘3’이 나올 확률 → **P(X = 3) = 1/6**
#
# ---
#
# ### 🔹 확률분포 (Probability Distribution)
#
# - **확률변수(X)** 와 그 값이 나올 수 있는 확률 **P(X)** 를 **대응시켜 표현한 것**을 확률분포라 한다.
# - 즉, 가능한 모든 값과 그 확률의 조합을 나타낸다.
#
# > 예시
# > - 주사위 눈금 X = {1, 2, 3, 4, 5, 6}
# > - 각 값의 확률 P(X=x) = 1/6
# > → 주사위의 확률분포는 균등분포(Uniform Distribution)
#
# ---
#
# ### 🔹 “확률분포를 따른다” 의 의미
#
# - 어떤 데이터가 특정한 분포의 성질을 갖고 있을 때
#   **“그 데이터는 그 확률분포를 따른다”** 라고 한다.
#
# > 예: 사람의 키가 평균 170cm, 표준편차 6cm의 정규분포를 따른다 →
# > 대부분의 사람 키는 평균 근처에 분포하고, 평균에서 멀어질수록 희귀해진다.
#
# ---
#
# ### 🔹 모집단과 확률변수의 관계
#
# - 모집단(Population)에서 **단순 랜덤 샘플링(Simple Random Sampling)** 으로 표본을 1개 추출하는 것은,
#   **모집단 분포에 따르는 확률변수 1개를 얻는 것과 같은 의미**로 볼 수 있다.
#
# > 즉,
# > 모집단의 분포를 **확률분포로**,
# > 그로부터 추출한 개별 표본을 **확률변수**로 이해할 수 있다.
#
# ---
#
# ### 💡 요약
#
# | 개념 | 의미 |
# |------|------|
# | **확률 (P)** | 어떤 사건이 일어날 가능성 |
# | **확률변수 (X)** | 확률에 의해 결정되는 변수 |
# | **확률분포** | 확률변수 X와 그 확률 P(X)의 대응 관계 |
# | **모집단 분포** | 표본이 추출되는 근본적인 확률분포 |
#
# ---
#
# ### 💡 예시 코드 (Python)
#
# ```python
# import numpy as np
# import matplotlib.pyplot as plt
# from scipy.stats import norm
#
# # 정규분포 확률밀도함수 (평균=0, 표준편차=1)
# x = np.linspace(-4, 4, 1000)
# y = norm.pdf(x, 0, 1)
#
# plt.plot(x, y)
# plt.title("정규분포 (평균=0, 표준편차=1)")
# plt.xlabel("x")
# plt.ylabel("P(X=x)")
# plt.show()
